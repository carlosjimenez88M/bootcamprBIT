# %% [markdown]
# ## Introducción al Machile Learning
#
# ### Notas de clase

# %%
import pandas as pd  #  Para trabajar con los datos 
import numpy as np # Operaciones 
import matplotlib.pyplot as plt # Hacer gráficos
import seaborn as sns # Hacer gráficos
from sklearn.datasets.samples_generator import make_blobs
from mpl_toolkits.mplot3d import Axes3D
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LinearRegression
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
X,y = make_blobs(n_samples = 1000, centers = 2 , cluster_std = 2.8, random_state=2021)
plt.scatter(X[:,0],X[:,1], c=y)
plt.title('Soy una Gráfica muy feliz !!!=)\n y ahora traigo datos de clusters')
# Out:
# Text(0.5, 1.0, 'Soy una Gráfica muy feliz !!!=)\n y ahora traigo datos de clusters')

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0],X[:,1], c=y)

# %%
clasificador = SGDClassifier(loss='hinge', alpha=0.1, max_iter=100, tol=0.01)
print('-'*64)
print()
print("Hola soy tu SVM !!! hicimos lo siguiente =)")
print()
print(clasificador.fit(X,y))
print()
print('-'*64)
# Out:
# ----------------------------------------------------------------
#
# Hola soy tu SVM !!! hicimos lo siguiente =)
#
# SGDClassifier(alpha=0.1, average=False, class_weight=None, early_stopping=False,
#               epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#               learning_rate='optimal', loss='hinge', max_iter=100,
#               n_iter_no_change=5, n_jobs=None, penalty='l2', power_t=0.5,
#               random_state=None, shuffle=True, tol=0.01,
#               validation_fraction=0.1, verbose=0, warm_start=False)
#
# ----------------------------------------------------------------

# %%
x_min , x_max = X[:,0].min() -0.5,X[:,0].max() + 0.5
y_min , y_max = X[:,1].min() -0.5,X[:,1].max() + 0.5
xx,yy = np.meshgrid(np.arange(x_min,x_max,0.05), np.arange(y_min,y_max,0.05))

# %%
## Aplicar mi modelito
mi_clf =clasificador.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)

# %%
plt.contour(xx,yy,mi_clf)
plt.scatter(X[:,0],X[:,1], c=y)
plt.title('Soy tu primer modelo de ML y estoy muy feliz!!')
# Out:
# Text(0.5, 1.0, 'Soy tu primer modelo de ML y estoy muy feliz!!')

# %% [markdown]
# ## Atacar un problema de regresión

# %%
a = .5
b = 1

x=20 * np.random.random(20)
y = a*x + b + np.random.normal(size=x.shape)

# %%
plt.scatter(x,y)

# %%
modelito_lineal = LinearRegression()
modelito_lineal.fit(x[:,None], y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(modelito_lineal.coef_)
print(modelito_lineal.intercept_)
# Out:
# [0.5066518]
# 0.8823604031783558

# %%
x_new = np.linspace(0,30,100)
y_new = modelito_lineal.predict(x_new[:,None])
plt.scatter(x,y)
plt.plot(x_new,y_new,'g-')
plt.title("Soy tu regresión Lineal! ")
# Out:
# Text(0.5, 1.0, 'Soy tu regresión Lineal! ')

# %% [markdown]
# ## Una intro formal al Machine Learnig

# %%
from sklearn.datasets import load_iris
iris = load_iris()
iris.keys()
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
## Convertir en una base de datos

iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)
iris_df['Species'] = iris.target
iris_df['Species'] =iris_df['Species'].astype('category')
iris_df['Species'].cat.categories = iris.target_names

# %%
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris_df,hue='Species')

# %%
X,y = iris.data, iris.target
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
pca.fit(X)
X_reducida = pca.transform(X)

# %%
plt.scatter(X_reducida[:,0],X_reducida[:,1], c=y)

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0],X[:,1], c=y)

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X_reducida[:,0],X_reducida[:,1], c=y)

# %%
from sklearn.manifold import Isomap
pca = Isomap(n_components=3)
pca.fit(X)
X_reducida2 = pca.transform(X)

# %%
plt.scatter(X_reducida2[:,0],X_reducida2[:,1],c=y)

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X_reducida2[:,0],X_reducida2[:,1], c=y)
