# %% [markdown]
# ## Regresión Lineal
#
# * Math (programación)
# * La algoritmia para hacerlo como gente de bien !!!

# %%
## Import libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D
import itertools
plt.style.use("fivethirtyeight")

# %%
## Import Dataset 
data = pd.read_csv('../data/data.csv')
data.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
datos = data[["price","bedrooms","sqft_lot"]]

# %%
datos["price"] = np.int64(data["price"])
datos["bedrooms"] = np.int64(data["bedrooms"])
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
datos.head()
# Out:
#      price  bedrooms  sqft_lot
# 0   313000         3      7912
# 1  2384000         5      9050
# 2   342000         3     11947
# 3   420000         3      8030
# 4   550000         4     10500

# %%
plt.scatter(datos['sqft_lot'].values,datos['price'].values)

# %% [markdown]
# ## ¿Cómo se normaliza la data?
#
# $$
# x = \frac{x - \hat{x}}{\lambda_x}
# $$

# %%
y_mean,y_std =datos['price'].values.mean(),datos['price'].values.std()
x_mean,x_std =datos['sqft_lot'].values.mean(),datos['sqft_lot'].values.std()

# %%
Y = (datos['price'].values -y_mean)/y_std
X = (datos['sqft_lot'].values -x_mean)/x_std

# %%
plt.scatter(X,Y)

# %% [markdown]
# ## Regresión Lineal

# %% [markdown]
# $$
# h_b= \beta_{0}+\beta_{1}+x_1
# $$
#
# * $h_b$ es la variable a predecir
# * $\beta_{0}$ : es intercerpecto
# * $\beta_{1}$ coeficiente o factor de explicación

# %% [markdown]
# ## Residuales
# $$
# SS_{residuales} = \sum_{i=1}(\hat{y}-y)^2
# $$

# %% [markdown]
# ## Función de costo
#
# $$
# J(\beta_{0},\beta_{1})=\frac{1}{2n}\sum_{i=1}^{m}(h_b(x_i)-y_i)^2
# $$

# %%
## Ejemplo practico
Y = datos['price'].values
X = datos['sqft_lot'].values
n_samples = X.shape[0]

# %%
X_ = np.c_[np.ones(n_samples),X]

# %%
beta_inicial = np.array([-1,1])

# %%
def lr_h(beta,x):
    return np.dot(beta, x.T)

# %%
plt.scatter(X,Y)
x = np.c_[np.ones(2),[X.min(),X.max()]]
plt.plot(x[:,1],lr_h(beta_inicial,x),'r',lw =2)

# %%
def lr_cost_func(beta,x,y):
    res=0
    for i in range(x.shape[0]):
        res += (lr_h(beta,x[i,:])-y[i])**2
    res *=1/(2*x.shape[0])
    return res

# %%
lr_cost_func(beta_inicial,X_,Y)
# Out:
# 302787745132.1936

# %%
beta0 = np.arange(-200,200,2)
beta1 = 10

# %%
cost_func=[]
for beta_0 in beta0:
    cost_func.append(lr_cost_func(np.array([beta_0, beta1]), X_, Y) )

plt.plot(beta0, cost_func)
plt.xlabel('beta_0')
plt.ylabel('J(beta)')
# Out:
# Text(0, 0.5, 'J(beta)')

# %%
beta0 = 0
beta1 = np.arange(-15, 20, 1)

# %%
cost_func=[]
for beta_1 in beta1:
    cost_func.append(lr_cost_func(np.array([beta0, beta_1]), X_, Y) )

plt.plot(beta1, cost_func)
plt.xlabel('beta_1')
plt.ylabel('J(beta)')
# Out:
# Text(0, 0.5, 'J(beta)')

# %%
beta0 = np.arange(-5, 7, 0.2)
beta1 = np.arange(-5, 7, 0.2)

# %%
cost_func = pd.DataFrame(index=beta0, columns=beta1)

for beta_0 in beta0:
    for beta_1 in beta1:
        cost_func.loc[beta_0, beta_1] = lr_cost_func(np.array([beta_0, beta_1]), X_, Y)

# %%
betas = np.transpose([np.tile(beta0, beta1.shape[0]), np.repeat(beta1, beta0.shape[0])])
fig = plt.figure(figsize=(10, 10))
ax = fig.gca(projection='3d')
ax.plot_trisurf(betas[:, 0], betas[:, 1], cost_func.T.values.flatten().astype('float'), linewidth=0.1)
ax.set_xlabel('beta_0')
ax.set_ylabel('beta_1')
ax.set_zlabel('J(beta)')
plt.show()

# %%
betas = np.array([[0, 0],
                 [-1, -1],
                 [-5, 5],
                 [3, -2]])

# %%
for beta in betas:
    print('\n\nLinear Regression with betas ', beta)
    f, (ax1, ax2) = plt.subplots(1,2, figsize=(12, 6))
    ax2.contour(beta0, beta1, cost_func.T.values)
    ax2.set_xlabel('beta_0')
    ax2.set_ylabel('beta_1')
    ax2.scatter(beta[0], beta[1], s=50)
    ax1.scatter(X, Y)
    x = np.c_[np.ones(2), [X.min(), X.max()]]
    ax1.plot(x[:, 1], lr_h(beta, x), 'r', lw=5)
    ax1.set_xlabel('Area')
    ax1.set_ylabel('Price')
    plt.show()
# Out:
# Linear Regression with betas  [0 0]
# Linear Regression with betas  [-1 -1]
# Linear Regression with betas  [-5  5]
# Linear Regression with betas  [ 3 -2]

# %%
beta_ini = np.array([-1.5, 0.])

def gradient(beta, x, y):
    
    gradient_0  = 1 / x.shape[0] * ((lr_h(beta, x) - y).sum())
    gradient_1  = 1 / x.shape[0] * ((lr_h(beta, x) - y)* x[:, 1]).sum()

    return np.array([gradient_0, gradient_1])

gradient(beta_ini, X_, Y)
# Out:
# array([-5.51964475e+05, -9.21861488e+09])

# %%
def gradient_descent(x, y, beta_ini, alpha, iters): 
    betas = np.zeros((iters, beta_ini.shape[0] + 1))

    beta = beta_ini
    for iter_ in range(iters):

        betas[iter_, :-1] = beta
        betas[iter_, -1] = lr_cost_func(beta, x, y)
        beta -= alpha * gradient(beta, x, y)
        
    return betas

# %%
iters = 100
alpha = 0.05
beta_ini = np.array([-1., 4.])

betas =  gradient_descent(X_, Y, beta_ini, alpha, iters)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in double_scalars
#   after removing the cwd from sys.path.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: overflow encountered in multiply
#
# /opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:38: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in subtract
#   if __name__ == '__main__':

# %%
plt.plot(range(iters), betas[:, -1])
plt.xlabel('iteration')
plt.ylabel('J(beta)')
# Out:
# Text(0, 0.5, 'J(beta)')

# %%
betas_ = betas[range(0, iters, 10), :-1]
for i, beta in enumerate(betas_):
    print('\n\nLas betas para mi regresión Lineal ', beta)
    f, (ax1, ax2) = plt.subplots(1,2, figsize=(12, 6))
    ax2.contour(beta0, beta1, cost_func.T.values)
    ax2.set_xlabel('beta_0')
    ax2.set_ylabel('beta_1')
    ax2.scatter(beta[0], beta[1], c='r', s=50)
    
    if i > 0:
        for beta_ in betas_[:i]:
            ax2.scatter(beta_[0], beta_[1], s=50)


    ax1.scatter(X, Y)


    x = np.c_[np.ones(2), [X.min(), X.max()]]
    ax1.plot(x[:, 1], lr_h(beta, x), 'r', lw=5)
    ax1.set_xlabel('Area')
    ax1.set_ylabel('Price')
    plt.show()
# Out:
# Las betas para mi regresión Lineal  [-1.  4.]
# Las betas para mi regresión Lineal  [-1.23610969e+74 -1.25505054e+79]
# Las betas para mi regresión Lineal  [-7.34174639e+152 -7.45424366e+157]
# Las betas para mi regresión Lineal  [-4.36055478e+231 -4.42737138e+236]
# Las betas para mi regresión Lineal  [-inf  nan]
# Las betas para mi regresión Lineal  [nan nan]
# Las betas para mi regresión Lineal  [nan nan]
# Las betas para mi regresión Lineal  [nan nan]
# Las betas para mi regresión Lineal  [nan nan]
# Las betas para mi regresión Lineal  [nan nan]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import StandardScaler
ss = StandardScaler(with_mean=True, with_std=True)

# %%
clf1 = LinearRegression()
clf2 = SGDRegressor( max_iter=10000,tol=None)

# %%
clf1.fit(datos[["bedrooms","sqft_lot"]], datos["price"])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
clf2.fit(datos[["bedrooms","sqft_lot"]],datos["price"])
# Out:
# SGDRegressor(alpha=0.0001, average=False, early_stopping=False, epsilon=0.1,
#              eta0=0.01, fit_intercept=True, l1_ratio=0.15,
#              learning_rate='invscaling', loss='squared_loss', max_iter=10000,
#              n_iter_no_change=5, penalty='l2', power_t=0.25, random_state=None,
#              shuffle=True, tol=None, validation_fraction=0.1, verbose=0,
#              warm_start=False)

# %%
X = datos[["bedrooms","sqft_lot"]].values
Y = datos["price"]
ss.fit(X.astype(np.float))
X = ss.transform(X.astype(np.float))
ss.mean_, ss.scale_
# Out:
# (array([3.40086957e+00, 1.48525161e+04]),
#  array([9.08749322e-01, 3.58805355e+04]))

# %%
x = np.array([3,7912])
x_scaled = ss.transform(x.reshape(1, -1))

# %%
clf1.predict(x.reshape(1, -1))
# Out:
# array([498753.85643352])

# %%
clf2.predict(x.reshape(1, -1)) * y_std + y_mean
# Out:
# array([-2.87437081e+21])

# %%
datos.head()

# %%
y_pred = clf1.predict(datos[["bedrooms","sqft_lot"]])

# %%
from sklearn import metrics
import numpy as np
print('MAE:', metrics.mean_absolute_error(datos['price'], y_pred))
print('MSE:', metrics.mean_squared_error(datos['price'], y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(datos['price'], y_pred)))
# Out:
# MAE: 234046.691216651
# MSE: 304654759145.6213
# RMSE: 551955.3959747303

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test,y_train,y_test = train_test_split(datos[["bedrooms","sqft_lot"]],
                                                  datos['price'], test_size=.3,
                                                 random_state=1234)

# %%
regr = RandomForestRegressor(max_depth=3, n_estimators=10,random_state=0)

# %%
regr.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=3, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=10, n_jobs=None, oob_score=False,
#                       random_state=0, verbose=0, warm_start=False)

# %%
predictions = regr.predict(X_test)

# %%
predictions
# Out:
# array([434270.22475336, 382070.85506215, 510956.83164597, ...,
#        607558.62453165, 417348.22912849, 607558.62453165])

# %%
pd.DataFrame(predictions,y_test.values)
# Out:
#                      0
# 402000   434270.224753
# 345000   382070.855062
# 1100000  510956.831646
# 4668000  965508.671940
# 206135   434270.224753
# ...                ...
# 1600000  510956.831646
# 165050   434270.224753
# 1039000  607558.624532
# 545000   417348.229128
# 650000   607558.624532
#
# [1380 rows x 1 columns]

# %%
errors= abs(predictions- y_test.values)

# %%
print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')
# Out:
# Mean Absolute Error: 245092.89 degrees.

# %%
MAPE = 100 *(errors/y_test)
MAPE
# Out:
# 327       8.027419
# 3734     10.745175
# 3016     53.549379
# 2654     79.316438
# 2442    110.672726
#            ...
# 1143     68.065198
# 3706    163.114344
# 338      41.524675
# 2355     23.422343
# 32        6.529442
# Name: price, Length: 1380, dtype: float64

# %%
print(MAPE[1:10].mean())
# Out:
# 78.47639209647825

# %%
(MAPE[MAPE>1]).dropna()
# Out:
# inf

# %%
MAPE = MAPE.replace([np.inf, -np.inf], np.nan).dropna()

# %%
np.mean(MAPE)
# Out:
# 49.81092199969075
